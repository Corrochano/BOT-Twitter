# %% [markdown]
# # Prueba Linkedin
# #### Pablo Álvarez García y Álvaro Corrochano López

# %%
# Importo Beautiful Soup
from bs4 import BeautifulSoup
# Importo requests para pillar el código html de donde quiera
import requests

# %%
web = requests.get('https://es.linkedin.com/jobs/search?keywords=inform%C3%A1tica&location=Madrid%2C%2BComunidad%2Bde%2BMadrid%2C%2BEspa%C3%B1a&trk=homepage-jobseeker_jobs-search-bar_search-submit&f_TP=1&sortBy=DD&f_PP=103374081&redirect=false&position=1&pageNum=0')

# %%
print(web.content)
# Out:
# b'<!DOCTYPE html><html lang="es"><head><meta name="pageKey" content="d_jobs_guest_search"><meta name="linkedin:pageTag" content="urlType=jserp_custom;emptyResult=false"><meta name="locale" content="es_ES"><meta id="config"data-app-id="com.linkedin.jobs-guest-frontend.d_web"data-custom-tracking-code=""data-tracking-page-type=""/><meta id="google-analytics-config"data-use-location-for-dp=""data-use-page-title=""/><link rel="canonical" href="https://es.linkedin.com/jobs/inform%C3%A1tica-empleos"><link rel="manifest" href="/homepage-guest/manifest.json" crossorigin="use-credentials"/><link rel="icon" href="https://static-exp1.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico"><script>function getDfd() {let yFn,nFn;const p=new Promise((y, n)=>{yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}window.lazyloader = getDfd();window.tracking = getDfd();window.impressionTracking = getDfd();window.ingraphTracking = getDfd();window.appDetection = getDfd();</script><script src="https://static-exp1.licdn.com/sc/h/ec4mdgijccslffs14mpzdyffn" async></script><meta name="description" content="Los 1 principales empleos del d\xc3\xada de Inform\xc3\xa1tica en Espa\xc3\xb1a. S\xc3\xa1cale el m\xc3\xa1ximo partido a tu red profesional y consigue que te contraten. Se a\xc3\xb1aden nuevos empleos para Inform\xc3\xa1tica a diario."><meta name="robots" content="noarchive"><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="litmsProfileName" content="jobs-guest-frontend"><meta charset="utf-8"><meta property="lnkd:url" content="https://es.linkedin.com/jobs/search?keywords=inform%C3%A1tica&amp;location=Madrid%2C%2BComunidad%2Bde%2BMadrid%2C%2BEspa%C3%B1a&amp;trk=homepage-jobseeker_jobs-search-bar_search-submit&amp;f_TP=1&amp;sortBy=DD&amp;f_PP=103374081&amp;redirect=false&amp;position=1&amp;pageNum=0"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:site" content="@LinkedIn"/><meta name="twitter:description" content="Los 1 principales empleos del d\xc3\xada de Inform\xc3\xa1tica en Espa\xc3\xb1a. S\xc3\xa1cale el m\xc3\xa1ximo partido a tu red profesional y consigue que te contraten. Se a\xc3\xb1aden nuevos empleos para Inform\xc3\xa1tica a diario."/><meta property="og:type" content="website"/><meta property="og:url" content="https://es.linkedin.com/jobs/inform%C3%A1tica-empleos"/><meta property="og:description" content="Los 1 principales empleos del d\xc3\xada de Inform\xc3\xa1tica en Espa\xc3\xb1a. S\xc3\xa1cale el m\xc3\xa1ximo partido a tu red profesional y consigue que te contraten. Se a\xc3\xb1aden nuevos empleos para Inform\xc3\xa1tica a diario."/><link rel="stylesheet" href="https://static-exp1.licdn.com/sc/h/dhg5nca77zd6f9ml8hom64ikq"/><title>1 empleos de Inform\xc3\xa1tica en Espa\xc3\xb1a (1\xc2\xa0nuevo/s)</title><meta property="og:title" content="1 empleos de Inform\xc3\xa1tica en Espa\xc3\xb1a (1\xc2\xa0nuevo/s)"/><meta name="twitter:title" content="1 empleos de Inform\xc3\xa1tica en Espa\xc3\xb1a (1\xc2\xa0nuevo/s)"/><meta name="clientSideIngraphs" content="1" data-gauge-metric-endpoint="/jobs-guest/api/ingraphs/gauge" data-counter-metric-endpoint="/jobs-guest/api/ingraphs/counter"/></head><body><div id="artdeco-global-alert-container"class="global-alert-banner"aria-live="assertive" role="alert"><div class="artdeco-global-alert artdeco-global-alert--NOTICE artdeco-global-alert--COOKIE_CONSENT"severity="NOTICE"alert-id="urn:li:alert:10"aria-hidden="true"type="COOKIE_CONSENT"><section class="artdeco-global-alert__body"><li-icon class="artdeco-global-alert__icon"><span><svg version="1.1"xmlns="http://www.w3.org/2000/svg"xmlns:xlink="http://www.w3.org/1999/xlink"height="24"width="24"><path d="M12,2C6.5,2,2,6.5,2,12c0,5.5,4.5,10,10,10c5.5,0,10-4.5,10-10C22,6.5,17.5,2,12,2zM12,20.2c-4.5,0-8.2-3.7-8.2-8.2S7.5,3.8,12,3.8s8.2,3.7,8.2,8.2S16.5,20.2,12,20.2zM11,10h2v8h-2V10zM11,6h2v2h-2V6z" fill="#fff"/></svg></span></li-icon><div class="artdeco-global-alert__responsive-container"><d ...

# %%
soup = BeautifulSoup(web.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta content="d_jobs_guest_search" name="pageKey"/>
#   <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
#   <meta content="es_ES" name="locale"/>
#   <meta data-app-id="com.linkedin.jobs-guest-frontend.d_web" data-custom-tracking-code="" data-tracking-page-type="" id="config">
#    <meta data-use-location-for-dp="" data-use-page-title="" id="google-analytics-config">
#     <link href="https://es.linkedin.com/jobs/inform%C3%A1tica-empleos" rel="canonical"/>
#     <link crossorigin="use-credentials" href="/homepage-guest/manifest.json" rel="manifest">
#      <link href="https://static-exp1.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico" rel="icon"/>
#      <script>
#       function getDfd() {let yFn,nFn;const p=new Promise((y, n)=>{yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}window.lazyloader = getDfd();window.tracking = getDfd();window.impressionTracking = getDfd();window.ingraphTracking = getDfd();window.appDetection = getDfd();
#      </script>
#      <script async="" src="https://static-exp1.licdn.com/sc/h/ec4mdgijccslffs14mpzdyffn">
#      </script>
#      <meta content="Los 1 principales empleos del día de Informática en España. Sácale el máximo partido a tu red profesional y consigue que te contraten. Se añaden nuevos empleos para Informática a diario." name="description"/>
#      <meta content="noarchive" name="robots"/>
#      <meta content="width=device-width, initial-scale=1" name="viewport">
#       <meta content="jobs-guest-frontend" name="litmsProfileName"/>
#       <meta charset="utf-8"/>
#       <meta content="https://es.linkedin.com/jobs/search?keywords=inform%C3%A1tica&amp;location=Madrid%2C%2BComunidad%2Bde%2BMadrid%2C%2BEspa%C3%B1a&amp;trk=homepage-jobseeker_jobs-search-bar_search-submit&amp;f_TP=1&amp;sortBy=DD&amp;f_PP=103374081&amp;redirect=false&amp;position=1&amp;pageNum=0" property="lnkd:url">
#        <meta content="summary_large_image" name="twitter:card">
#         <meta content="@LinkedIn" name="twitter:site">
#          <meta content="Los 1 principales empleos del día de Informática en España. Sácale el máximo partido a tu red profesional y consigue que te contraten. Se añaden nuevos empleos para Informática a diario." name="twitter:description">
#           <meta content="website" property="og:type"/>
#           <meta content="https://es.linkedin.com/jobs/inform%C3%A1tica-empleos" property="og:url"/>
#           <meta content="Los 1 principales empleos del día de Informática en España. Sácale el máximo partido a tu red profesional y consigue que te contraten. Se añaden nuevos empleos para Informática a diario." property="og:description"/>
#           <link href="https://static-exp1.licdn.com/sc/h/dhg5nca77zd6f9ml8hom64ikq" rel="stylesheet">
#            <title>
#             1 empleos de Informática en España (1 nuevo/s)
#            </title>
#            <meta content="1 empleos de Informática en España (1 nuevo/s)" property="og:title"/>
#            <meta content="1 empleos de Informática en España (1 nuevo/s)" name="twitter:title"/>
#            <meta content="1" data-counter-metric-endpoint="/jobs-guest/api/ingraphs/counter" data-gauge-metric-endpoint="/jobs-guest/api/ingraphs/gauge" name="clientSideIngraphs"/>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div aria-live="assertive" class="global-alert-banner" id="artdeco-global-alert-container" role="alert">
#    <div alert-id="urn:li:alert:10" aria-hidden="true" class="artdeco-global-alert artdeco-global-alert--NOTICE artdeco-global-alert--COOKIE_CONSENT" severity="NOTICE" type="COOKIE_CONSENT">
#     <section class="artdeco-global-alert__body">
#      <li-icon class="artdeco-global-alert__icon">
#       <span>
#        <svg height="24" version="1.1" width="24" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <path d="M12,2C6.5,2,2,6.5,2,12c0,5.5,4.5,10,10,10c5.5,0,10-4.5,10-10C22,6.5,17.5,2,12,2zM12,20.2c-4.5,0-8.2-3.7-8.2-8.2S7.5,3.8,12,3.8s8.2,3.7,8.2,8.2S16.5,20.2,12,20.2zM11,10h2v8h-2V10zM11,6h2v2h-2V6z" fill="#fff">
#         </path>
#        </svg>
#       </span>
#      </li-icon>
#      <div class="artdeco-global-alert__responsive-container">
#       <div class="artdeco-global-alert__content">
#        <p>
#         Nosotros y algunos terceros, como clientes, socios y proveedores de servicios, utilizamos cookies y tecnologías similares («cookies») para proporcionar y proteger nuestros servicios, para comprender y mejorar su rendimiento, y para publicar anuncios relevantes (incluidos anuncios de empleo) dentro y fuera LinkedIn. Consulta más información en nuestra
#         <a href="https://www.linkedin.com/legal/cookie-policy">
#          Política de cookies
#         </a>
#         .
#        </p>
#        <p>
#         Selecciona
#         <b>
#          «Aceptar cookies»
#         </b>
#         para dar tu consentimiento a este uso o
#         <b>
#          «Gestionar preferencias»
#         </b>
#         para seleccionar qué cookies autorizar. Puedes cambiar las opciones de las cookies y retirar el consentimiento en cualquier momento desde la configuración.
#        </p>
#       </div>
#       <div class="artdeco-global-alert-action__wrapper">
#        <button action-type="LINK" class="artdeco-global-alert-action artdeco-button artdeco-button--inverse artdeco-button--2 artdeco-button--primary" data-control-name="urn:li:control:ga-cookie.consent.manage.cookie.v3" data-tracking-control-name="urn:li:control:ga-cookie.consent.manage.cookie.v3">
#         Gestionar preferencias
#        </button>
#        <button action-type="ACCEPT" class="artdeco-global-alert-action artdeco-button artdeco-button--inverse artdeco-button--2 artdeco-button--primary" data-control-name="urn:li:control:ga-cookie.consent.accept.v3" data-tracking-control-name="urn:li:control:ga-cookie.consent.accept.v3">
#         Aceptar cookies
#        </button>
#       </div>
#      </div>
#     </section>
#    </div>
#    <div alert-id="urn:li:alert:3" aria-hidden="true" class="artdeco-global-alert artdeco-global-alert--NOTICE artdeco-global-alert--COOKIE_USAGE" severity="NOTICE" type="COOKIE_USAGE">
#     <section class="artdeco-global-alert__body">
#      <li-icon class="artdeco-global-alert__icon">
#       <span>
#        <svg height="24" version="1.1" width="24" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <path d="M12,2C6.5,2,2,6.5,2,12c0,5.5,4.5,10,10,10c5.5,0,10-4.5,10-10C22,6.5,17.5,2,12,2zM12,20.2c-4.5,0-8.2-3.7-8.2-8.2S7.5,3.8,12,3.8s8.2,3.7,8.2,8.2S16.5,20.2,12,20.2zM11,10h2v8h-2V10zM11,6h2v2h-2V6z" fill="#fff">
#         </path>
#        </svg>
#       </span>
#      </li-icon>
#      <div class="artdeco-global-alert__responsive-container">
#       <div class="artdeco-global-alert__content">
#        Este sitio web utiliza cookies para ofrecer un mejor servicio y proporcionar anuncios hechos a medida. Al utilizar este sitio web, aceptas dicho uso. Consulta nuestra
#        <a href="https://www.linkedin.com/legal/cookie-policy">
#         Política de cookies
#        </a>
#        .
#       </div>
#      </div>
#      <button class="artdeco-global-alert__dismiss">
#       <li-icon class="artdeco-global-alert__icon artdeco-global-alert__icon--dismissed">
#        <span>
#         <svg height="16" version="1.1" width="16" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#          <path d="M13,4.32L9.31,8,13,11.69,11.69,13,8,9.31,4.31,13,3,11.69,6.69,8,3,4.31,4.31,3,8,6.69,11.68,3Z" fill="#fff">
#          </path>
#         </svg>
#        </span>
#        <span class="a11y-text">
#         dismiss
#        </span>
#       </li-icon>
#      </button>
#     </section>
#    </div>
#   </div>
#   <script async="" defer="" src="https://static-exp1.licdn.com/sc/h/4n7pzwq49ctyurgru63dns535">
#   </script>
#   <a class="skip-link" href="#main-content">
#    Pasar al contenido principal
#   </a>
#   <header class="header">
#    <nav aria-label="Principal" class="nav">
#     <a class="nav__logo-link" data-tracking-control-name="public_jobs_nav-header-logo" data-tracking-will-navigate="" href="/?trk=public_jobs_nav-header-logo">
#      <span class="sr-only">
#       LinkedIn
#      </span>
#      <icon class="nav-logo" data-delayed-url="https://static-exp1.licdn.com/sc/h/8fkga714vy9b2wk5auqo5reeb">
#      </icon>
#     </a>
#     <section class="search-bar" data-current-search-type="JOBS">
#      <button aria-label="Ampliar búsqueda" class="search-bar__placeholder show-on-mobile hide-on-desktop" data-tracking-control-name="public_jobs_search-switcher-opener">
#       <div class="search-bar__full-placeholder">
#        Informática en España
#       </div>
#      </button>
#      <div class="switcher-tabs__trigger-and-tabs">
#       <button aria-expanded="false" class="switcher-tabs__placeholder hide-on-mobile" data-tracking-control-name="public_jobs_switcher-tabs-placeholder">
#        <span class="switcher-tabs__placeholder-text">
#        </span>
#        <icon class="switcher-tabs__caret-down-filled onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv">
#        </icon>
#       </button>
#       <div class="switcher-tabs hide-on-desktop hide-on-mobile">
#        <ul aria-labelledby="switcher-label" class="switcher-tabs__list">
#         <li class="switcher-tabs__tab switcher-tabs__tab--active">
#          <button class="switcher-tabs__button" data-switcher-type="JOBS" data-tracking-control-name="public_jobs_switcher-tabs-jobs-search-switcher" type="button">
#           Empleos
#          </button>
#         </li>
#         <li class="switcher-tabs__tab">
#          <button class="switcher-tabs__button" data-switcher-type="PEOPLE" data-tracking-control-name="public_jobs_switcher-tabs-people-search-switcher" type="button">
#           Personas
#          </button>
#         </li>
#         <li class="switcher-tabs__tab">
#          <button class="switcher-tabs__button" data-switcher-type="LEARNING" data-tracking-control-name="public_jobs_switcher-tabs-learning-search-switcher" type="button">
#           Formación
#          </button>
#         </li>
#        </ul>
#        <button class="switcher-tabs__cancel-btn hide-on-desktop" data-tracking-control-name="public_jobs_switcher-tabs-cancel-search-switcher" type="button">
#         <icon class="switcher-tabs__cancel-icon onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7">
#         </icon>
#        </button>
#       </div>
#      </div>
#      <section class="base-search-bar" data-searchbar-type="PEOPLE">
#       <form action="/pub/dir" class="base-search-bar__form" data-tracking-control-name="public_jobs_people-search-bar_base-search-bar-form" role="search">
#        <section class="dismissable-input search-input">
#         <input aria-label="Nombre" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_people-search-bar_first-name_dismissable-input" maxlength="500" name="firstName" placeholder="Nombre" type="search" value=""/>
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_people-search-bar_first-name_dismissable-input-clear" type="button">
#          <label class="screen-reader-text">
#           Descartar
#          </label>
#          <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7">
#          </icon>
#         </button>
#        </section>
#        <section class="dismissable-input search-input">
#         <input aria-label="Apellidos" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_people-search-bar_last-name_dismissable-input" maxlength="500" name="lastName" placeholder="Apellidos" type="search" value=""/>
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_people-search-bar_last-name_dismissable-input-clear" type="button">
#          <label class="screen-reader-text">
#           Descartar
#          </label>
#          <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7">
#          </icon>
#         </button>
#        </section>
#        <input name="trk" type="hidden" value="public_jobs_people-search-bar_search-submit">
#         <button aria-label="Buscar" class="base-search-bar__submit-btn" data-tracking-control-name="public_jobs_people-search-bar_base-search-bar-search-submit" type="submit">
#          <icon class="base-search-bar__search-icon onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/a6wnw1b2dk8748w5uni4o96fa">
#          </icon>
#         </button>
#        </input>
#       </form>
#      </section>
#      <section class="base-search-bar" data-searchbar-type="JOBS">
#       <form action="/jobs/search" class="base-search-bar__form" data-tracking-control-name="public_jobs_jobs-search-bar_base-search-bar-form" role="search">
#        <code id="i18n_aria_live_text_no-suggestions" style="display: none;">
#         <!--"No se ha encontrado ninguna sugerencia."-->
#        </code>
#        <code id="i18n_aria_live_text_one-suggestion" style="display: none;">
#         <!--"Una sugerencia. Utiliza las flechas para navegar. "-->
#        </code>
#        <code id="i18n_aria_live_text_multiple-suggestions" style="display: none;">
#         <!--"Varias sugerencias. Utiliza las flechas para navegar. "-->
#        </code>
#        <section aria-haspopup="listbox" aria-owns="job-search-bar-keywords-typeahead-list" class="dismissable-input typeahead-input keywords-typeahead-input" role="combobox">
#         <input aria-autocomplete="list" aria-controls="job-search-bar-keywords-typeahead-list" aria-label="Buscar cargos o empresas" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_jobs-search-bar_dismissable-input" maxlength="500" name="keywords" placeholder="Buscar cargos o empresas" type="search" value="Informática"/>
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_jobs-search-bar_dismissable-input-clear" type="button">
#          <label class="screen-reader-text">
#           Descartar
#          </label>
#          <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7">
#          </icon>
#         </button>
#         <div class="typeahead-input__dropdown">
#          <template class="typeahead-item-template">
#           <li class="typeahead-input__dropdown-item" role="option">
#            <span class="typeahead-input__dropdown-text">
#            </span>
#           </li>
#          </template>
#          <ul class="typeahead-input__dropdown-list" id="job-search-bar-keywords-typeahead-list" role="listbox">
#          </ul>
#         </div>
#        </section>
#        <code id="i18n_aria_live_text_no-suggestions" style="display: none;">
#         <!--"No se ha encontrado ninguna sugerencia."-->
#        </code>
#        <code id="i18n_aria_live_text_one-suggestion" style="display: none;">
#         <!--"Una sugerencia. Utiliza las flechas para navegar. "-->
#        </code>
#        <code id="i18n_aria_live_text_multiple-suggestions" style="display: none;">
#         <!--"Varias sugerencias. Utiliza las flechas para navegar. "-->
#        </code>
#        <section aria-haspopup="listbox" aria-owns="job-search-bar-location-typeahead-list" class="dismissable-input typeahead-input location-typeahead-input" role="combobox">
#         <input aria-autocomplete="list" aria-controls="job-search-bar-location-typeahead-list" aria-label="Ubicación" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_jobs-search-bar_dismissable-input" maxlength="500" name="location" placeholder="Ubicación" type="search" value="España"/>
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_jobs-search-bar_dismissable-input-clear" type="button">
#          <label class="screen-reader-text">
#           Descartar
#          </label>
#          <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7">
#          </icon>
#         </button>
#         <div class="typeahead-input__dropdown">
#          <template class="typeahead-item-template">
#           <li class="typeahead-input__dropdown-item" role="option">
#            <span class="typeahead-input__dropdown-text">
#            </span>
#           </li>
#          </template>
#          <ul class="typeahead-input__dropdown-list" id="job-search-bar-location-typeahead-list" role="listbox">
#          </ul>
#         </div>
#        </section>
#        <input name="geoId" type="hidden" value="105646813">
#         <input name="trk" type="hidden" value="public_jobs_jobs-search-bar_search-submit">
#          <button aria-label="Buscar" class="base-search-bar__submit-btn" data-tracking-control-name="public_jobs_jobs-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/a6wnw1b2dk8748w5uni4o96fa">
#           </icon>
#          </button>
#         </input>
#        </input>
#       </form>
#      </section>
#      <section class="base-search-bar" data-searchbar-type="LEARNING">
#       <form action="/learning/search" class="base-search-bar__form" data-tracking-control-name="public_jobs_learning-search-bar_base-search-bar-form" role="search">
#        <section class="dismissable-input search-input">
#         <input aria-label="Busca aptitudes, temas o software" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_learning-search-bar_keywords_dismissable-input" maxlength="500" name="keywords" placeholder="Busca aptitudes, temas o software" type="search" value="Informática"/>
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_learning-search-bar_keywords_dismissable-input-clear" type="button">
#          <label class="screen-reader-text">
#           Descartar
#          </label>
#          <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7">
#          </icon>
#         </button>
#        </section>
#        <!--  this input class name can not be changed, this is what tracking.js on LGFE is expecting-->
#        <input class="nav__search-uoo" name="upsellOrderOrigin" type="hidden">
#         <input name="trk" type="hidden" value="public_jobs_learning-search-bar_search-submit">
#          <button aria-label="Buscar" class="base-search-bar__submit-btn" data-tracking-control-name="public_jobs_learning-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/a6wnw1b2dk8748w5uni4o96fa">
#           </icon>
#          </button>
#         </input>
#        </input>
#       </form>
#      </section>
#      <div aria-live="polite" class="search-bar__live-text sr-only" role="status">
#      </div>
#     </section>
#     <div class="nav__cta-container">
#      <a class="nav__button-tertiary" data-tracking-control-name="public_jobs_nav-header-join" data-tracking-will-navigate="" href="https://www.linkedin.com/signup/cold-join?source=jobs_registration&amp;session_redirect=https%3A%2F%2Fes.linkedin.com%2Fjobs%2Fsearch%3Fkeywords%3Dinform%25C3%25A1tica%26location%3DMadrid%252C%252BComunidad%252Bde%252BMadrid%252C%252BEspa%25C3%25B1a%26trk%3Dhomepage-jobseeker_jobs-search-bar_search-submit%26f_TP%3D1%26sortBy%3DDD%26f_PP%3D103374081%26redirect%3Dfalse%26position%3D1%26pageNum%3D0&amp;trk=public_jobs_nav-header-join">
#       Unirse ahora
#      </a>
#      <a class="nav__button-secondary" data-tracking-control-name="public_jobs_nav-header-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?emailAddress=&amp;fromSignIn=true&amp;session_redirect=https%3A%2F%2Fes.linkedin.com%2Fjobs%2Fsearch%3Fkeywords%3Dinform%25C3%25A1tica%26location%3DMadrid%252C%252BComunidad%252Bde%252BMadrid%252C%252BEspa%25C3%25B1a%26trk%3Dhomepage-jobseeker_jobs-search-bar_search-submit%26f_TP%3D1%26sortBy%3DDD%26f_PP%3D103374081%26redirect%3Dfalse%26position%3D1%26pageNum%3D0&amp;trk=public_jobs_nav-header-signin">
#       Iniciar sesión
#      </a>
#     </div>
#    </nav>
#    <section class="control-bar">
#     <code id="num-selected-filters" style="display: none;">
#      <!--"+3 filters"-->
#     </code>
#     <form class="top-filters">
#      <ul class="top-filters__list">
#       <li class="top-filters__item">
#        <div class="filter-dropdown filter-dropdown--single filter-dropdown--has-selected filter-dropdown--guest-house filter-button-dropdown">
#         <button aria-controls="-dropdown" aria-expanded="false" class="filter-dropdown__button filter-button filter-button--single filter-button--has-selected filter-button--guest-house" data-tracking-control-name="public_jobs_-dropdown" type="button">
#          Más recientes
#          <icon class="filter-button__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv">
#          </icon>
#         </button>
#         <div class="filter-dropdown__dropdown" id="-dropdown">
#          <fieldset>
#           <legend class="sr-only">
#            Ordenar por
#           </legend>
#           <div class="filter-list" data-is-single-select="true" data-short-name="sortBy">
#            <ul class="filter-list__list">
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="-0" name="sortBy" type="radio" value="R"/>
#              <label class="filter-list__list-item-label" for="-0">
#               Más relevantes
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input checked="" id="-1" name="sortBy" type="radio" value="DD"/>
#              <label class="filter-list__list-item-label" for="-1">
#               Más recientes
#              </label>
#             </li>
#            </ul>
#           </div>
#           <div class="filter-button-dropdown__dropdown-actions">
#            <button class="filter-button-dropdown__action filter-button-dropdown__action--apply" data-tracking-control-name="sortBy-done-btn" data-tracking-will-navigate="" type="submit">
#             Listo
#            </button>
#           </div>
#          </fieldset>
#         </div>
#        </div>
#       </li>
#       <li class="top-filters__item">
#        <div class="filter-dropdown filter-dropdown--single filter-dropdown--has-selected filter-dropdown--guest-house filter-button-dropdown">
#         <button aria-controls="TIME_POSTED-dropdown" aria-expanded="false" class="filter-dropdown__button filter-button filter-button--single filter-button--has-selected filter-button--guest-house" data-tracking-control-name="public_jobs_TIME_POSTED-dropdown" type="button">
#          Últimas 24 horas
#          <icon class="filter-button__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv">
#          </icon>
#         </button>
#         <div class="filter-dropdown__dropdown" id="TIME_POSTED-dropdown">
#          <fieldset>
#           <legend class="sr-only">
#            Fecha de publicación
#           </legend>
#           <div class="filter-list" data-is-single-select="true" data-short-name="f_TP">
#            <ul class="filter-list__list">
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input checked="" id="TIME_POSTED-0" name="f_TP" type="radio" value="1"/>
#              <label class="filter-list__list-item-label" for="TIME_POSTED-0">
#               Últimas 24 horas
#               <span class="filter-list__label-count">
#                (1)
#               </span>
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="TIME_POSTED-1" name="f_TP" type="radio" value="1,2"/>
#              <label class="filter-list__list-item-label" for="TIME_POSTED-1">
#               Semana pasada
#               <span class="filter-list__label-count">
#                (36)
#               </span>
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="TIME_POSTED-2" name="f_TP" type="radio" value="1,2,3,4"/>
#              <label class="filter-list__list-item-label" for="TIME_POSTED-2">
#               Mes pasado
#               <span class="filter-list__label-count">
#                (345)
#               </span>
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="TIME_POSTED-3" name="f_TP" type="radio" value=""/>
#              <label class="filter-list__list-item-label" for="TIME_POSTED-3">
#               Cualquier momento
#              </label>
#             </li>
#            </ul>
#           </div>
#           <div class="filter-button-dropdown__dropdown-actions">
#            <button class="filter-button-dropdown__action filter-button-dropdown__action--apply" data-tracking-control-name="f_TP-done-btn" data-tracking-will-navigate="" type="submit">
#             Listo
#            </button>
#           </div>
#          </fieldset>
#         </div>
#        </div>
#       </li>
#       <li class="top-filters__item">
#        <div class="filter-dropdown filter-dropdown--single filter-dropdown--has-selected filter-dropdown--guest-house filter-button-dropdown">
#         <button aria-controls="POPULATED_PLACE-dropdown" aria-expanded="false" class="filter-dropdown__button filter-button filter-button--single filter-button--has-selected filter-button--guest-house" data-tracking-control-name="public_jobs_POPULATED_PLACE-dropdown" type="button">
#          Madrid
#          <icon class="filter-button__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv">
#          </icon>
#         </button>
#         <div class="filter-dropdown__dropdown" id="POPULATED_PLACE-dropdown">
#          <fieldset>
#           <legend class="sr-only">
#            Ubicación
#           </legend>
#           <div class="filter-list" data-is-single-select="" data-short-name="f_PP">
#            <code id="i18n_live_region_no-suggestions" style="display: none;">
#             <!--"No se ha encontrado ninguna sugerencia."-->
#            </code>
#            <code id="i18n_live_region_one-suggestion" style="display: none;">
#             <!--"Una sugerencia. Utiliza las flechas para navegar. "-->
#            </code>
#            <code id="i18n_live_region_multiple-suggestions" style="display: none;">
#             <!--"Varias sugerencias. Utiliza las flechas para navegar. "-->
#            </code>
#            <div class="typeahead filter-button-dropdown__typeahead" id="filter-button-facet-typeahead-f_PP">
#             <div aria-live="polite" class="sr-only" id="live-region" role="status">
#             </div>
#             <input aria-activedescendant="" aria-autocomplete="list" aria-expanded="false" aria-label="Añadir un filtro para Ubicación" aria-owns="filter-button-facet-typeahead-f_PP-suggestions-list" class="typeahead__input" id="filter-button-facet-typeahead-f_PP-input" name="value" placeholder="Añadir un filtro" role="combobox" type="text" value=""/>
#             <button class="typeahead__button" type="button">
#              <span class="sr-only">
#               Descartar
#              </span>
#              <icon data-delayed-url="https://static-exp1.licdn.com/sc/h/c62wbyjzgy67o1dm9umuzlx8z">
#              </icon>
#             </button>
#             <div class="typeahead-dropdown">
#              <ul class="typeahead-dropdown__list" id="filter-button-facet-typeahead-f_PP-suggestions-list" role="listbox">
#              </ul>
#             </div>
#            </div>
#            <ul class="filter-list__list">
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input checked="" id="POPULATED_PLACE-0" name="f_PP" type="checkbox" value="103374081"/>
#              <label class="filter-list__list-item-label" for="POPULATED_PLACE-0">
#               Madrid
#               <span class="filter-list__label-count">
#                (1)
#               </span>
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="POPULATED_PLACE-1" name="f_PP" type="checkbox" value="105088894"/>
#              <label class="filter-list__list-item-label" for="POPULATED_PLACE-1">
#               Barcelona
#               <span class="filter-list__label-count">
#                (1)
#               </span>
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="POPULATED_PLACE-2" name="f_PP" type="checkbox" value="105512687"/>
#              <label class="filter-list__list-item-label" for="POPULATED_PLACE-2">
#               Valencia/València
#               <span class="filter-list__label-count">
#                (1)
#               </span>
#              </label>
#             </li>
#            </ul>
#           </div>
#           <div class="filter-button-dropdown__dropdown-actions">
#            <button class="filter-button-dropdown__action filter-button-dropdown__action--apply" data-tracking-control-name="f_PP-done-btn" data-tracking-will-navigate="" type="submit">
#             Listo
#            </button>
#           </div>
#          </fieldset>
#         </div>
#        </div>
#       </li>
#       <li class="top-filters__item">
#        <div class="filter-dropdown filter-dropdown--single filter-dropdown--none-selected filter-dropdown--guest-house filter-button-dropdown">
#         <button aria-controls="COMPANY-dropdown" aria-expanded="false" class="filter-dropdown__button filter-button filter-button--single filter-button--none-selected filter-button--guest-house" data-tracking-control-name="public_jobs_COMPANY-dropdown" type="button">
#          Empresa
#          <icon class="filter-button__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv">
#          </icon>
#         </button>
#         <div class="filter-dropdown__dropdown" id="COMPANY-dropdown">
#          <fieldset>
#           <legend class="sr-only">
#            Empresa
#           </legend>
#           <div class="filter-list" data-is-single-select="" data-short-name="f_C">
#            <code id="i18n_live_region_no-suggestions" style="display: none;">
#             <!--"No se ha encontrado ninguna sugerencia."-->
#            </code>
#            <code id="i18n_live_region_one-suggestion" style="display: none;">
#             <!--"Una sugerencia. Utiliza las flechas para navegar. "-->
#            </code>
#            <code id="i18n_live_region_multiple-suggestions" style="display: none;">
#             <!--"Varias sugerencias. Utiliza las flechas para navegar. "-->
#            </code>
#            <div class="typeahead filter-button-dropdown__typeahead" id="filter-button-facet-typeahead-f_C">
#             <div aria-live="polite" class="sr-only" id="live-region" role="status">
#             </div>
#             <input aria-activedescendant="" aria-autocomplete="list" aria-expanded="false" aria-label="Añadir un filtro para Empresa" aria-owns="filter-button-facet-typeahead-f_C-suggestions-list" class="typeahead__input" id="filter-button-facet-typeahead-f_C-input" name="value" placeholder="Añadir un filtro" role="combobox" type="text" value=""/>
#             <button class="typeahead__button" type="button">
#              <span class="sr-only">
#               Descartar
#              </span>
#              <icon data-delayed-url="https://static-exp1.licdn.com/sc/h/c62wbyjzgy67o1dm9umuzlx8z">
#              </icon>
#             </button>
#             <div class="typeahead-dropdown">
#              <ul class="typeahead-dropdown__list" id="filter-button-facet-typeahead-f_C-suggestions-list" role="listbox">
#              </ul>
#             </div>
#            </div>
#            <ul class="filter-list__list">
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="COMPANY-0" name="f_C" type="checkbox" value="763079"/>
#              <label class="filter-list__list-item-label" for="COMPANY-0">
#               serem. Consultoría empresarial
#               <span class="filter-list__label-count">
#                (1)
#               </span>
#              </label>
#             </li>
#            </ul>
#           </div>
#           <div class="filter-button-dropdown__dropdown-actions">
#            <button class="filter-button-dropdown__action filter-button-dropdown__action--apply" data-tracking-control-name="f_C-done-btn" data-tracking-will-navigate="" type="submit">
#             Listo
#            </button>
#           </div>
#          </fieldset>
#         </div>
#        </div>
#       </li>
#       <li class="top-filters__item">
#        <div class="filter-dropdown filter-dropdown--single filter-dropdown--none-selected filter-dropdown--guest-house filter-button-dropdown">
#         <button aria-controls="JOB_TYPE-dropdown" aria-expanded="false" class="filter-dropdown__button filter-button filter-button--single filter-button--none-selected filter-button--guest-house" data-tracking-control-name="public_jobs_JOB_TYPE-dropdown" type="button">
#          Tipo de empleo
#          <icon class="filter-button__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv">
#          </icon>
#         </button>
#         <div class="filter-dropdown__dropdown" id="JOB_TYPE-dropdown">
#          <fieldset>
#           <legend class="sr-only">
#            Tipo de empleo
#           </legend>
#           <div class="filter-list" data-is-single-select="" data-short-name="f_JT">
#            <ul class="filter-list__list">
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="JOB_TYPE-0" name="f_JT" type="checkbox" value="F"/>
#              <label class="filter-list__list-item-label" for="JOB_TYPE-0">
#               Jornada completa
#               <span class="filter-list__label-count">
#                (1)
#               </span>
#              </label>
#             </li>
#            </ul>
#           </div>
#           <div class="filter-button-dropdown__dropdown-actions">
#            <button class="filter-button-dropdown__action filter-button-dropdown__action--apply" data-tracking-control-name="f_JT-done-btn" data-tracking-will-navigate="" type="submit">
#             Listo
#            </button>
#           </div>
#          </fieldset>
#         </div>
#        </div>
#       </li>
#       <li class="top-filters__item">
#        <div class="filter-dropdown filter-dropdown--single filter-dropdown--none-selected filter-dropdown--guest-house filter-button-dropdown">
#         <button aria-controls="EXPERIENCE-dropdown" aria-expanded="false" class="filter-dropdown__button filter-button filter-button--single filter-button--none-selected filter-button--guest-house" data-tracking-control-name="public_jobs_EXPERIENCE-dropdown" type="button">
#          Nivel de experiencia
#          <icon class="filter-button__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv">
#          </icon>
#         </button>
#         <div class="filter-dropdown__dropdown" id="EXPERIENCE-dropdown">
#          <fieldset>
#           <legend class="sr-only">
#            Nivel de experiencia
#           </legend>
#           <div class="filter-list" data-is-single-select="" data-short-name="f_E">
#            <ul class="filter-list__list">
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="EXPERIENCE-0" name="f_E" type="checkbox" value="2"/>
#              <label class="filter-list__list-item-label" for="EXPERIENCE-0">
#               Sin experiencia
#               <span class="filter-list__label-count">
#                (1)
#               </span>
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="EXPERIENCE-1" name="f_E" type="checkbox" value="1"/>
#              <label class="filter-list__list-item-label" for="EXPERIENCE-1">
#               Prácticas
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="EXPERIENCE-2" name="f_E" type="checkbox" value="3"/>
#              <label class="filter-list__list-item-label" for="EXPERIENCE-2">
#               Algo de responsabilidad
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="EXPERIENCE-3" name="f_E" type="checkbox" value="4"/>
#              <label class="filter-list__list-item-label" for="EXPERIENCE-3">
#               Intermedio
#              </label>
#             </li>
#             <li class="filter-list__list-item filter-button-dropdown__list-item">
#              <input id="EXPERIENCE-4" name="f_E" type="checkbox" value="5"/>
#              <label class="filter-list__list-item-label" for="EXPERIENCE-4">
#               Director
#              </label>
#             </li>
#            </ul>
#           </div>
#           <div class="filter-button-dropdown__dropdown-actions">
#            <button class="filter-button-dropdown__action filter-button-dropdown__action--apply" data-tracking-control-name="f_E-done-btn" data-tracking-will-navigate="" type="submit">
#             Listo
#            </button>
#           </div>
#          </fieldset>
#         </div>
#        </div>
#       </li>
#       <li class="top-filters__item top-filters__item--clear">
#        <button class="top-filters__clear-button" data-tracking-control-name="public_jobs_top-filters-clear-btn" data-tracking-will-navigate="">
#         Quitar filtros
#        </button>
#       </li>
#      </ul>
#      <mark class="top-filters__count">
#       <abbr class="top-filters__count--value">
#        3
#       </abbr>
#      </mark>
#     </form>
#    </section>
#   </header>
#   <main class="results results--two-pane" id="main-content" role="main">
#    <div class="results__container results__container--two-pane">
#     <section class="results__list">
#      <div class="create-alert-modal-outlet__container create-alert-modal-outlet__container--toggle create-alert-modal-outlet__container--toggle-secondary">
#       <div class="create-alert-modal-outlet__toggle-text">
#        <div class="create-job-alert-outlet__toggle-text-container">
#         <span>
#          Activar alertas de empleo
#         </span>
#        </div>
#       </div>
#       <div class="create-alert-modal-outlet__toggle" data-modal="create-alert-modal-outlet">
#        <div class="toggle">
#         <input class="toggle__checkbox" data-tracking-control-name="public_jobs_create-alert-modal-outlet__toggle" id="toggle-public_jobs_create-alert-modal-outlet__toggle" name="toggle-public_jobs_create-alert-modal-outlet__toggle" type="checkbox"/>
#         <label aria-label="" class="toggle__label" for="toggle-public_jobs_create-alert-modal-outlet__toggle">
#          <span class="toggle__label-text toggle__label-text--checked">
#           Activado
#          </span>
#          <span class="toggle__label-text toggle__label-text--unchecked">
#           Desactivado
#          </span>
#         </label>
#        </div>
#       </div>
#      </div>
#      <div class="results-context-header">
#       <h1 class="results-context-header__context">
#        <span class="results-context-header__job-count">
#         1
#        </span>
#        <span class="results-context-header__query-search">
#         Resultados para «empleos de Informática en España»
#        </span>
#        <span class="results-context-header__new-jobs">
#         (1 nuevo)
#        </span>
#       </h1>
#      </div>
#      <ul class="jobs-search__results-list">
#       <li class="result-card job-result-card result-card--with-hover-state" data-column="1" data-entity-urn="urn:li:jobPosting:2365648116" data-id="2365648116" data-row="1" data-search-id="e8242f45-cc09-41fb-9378-693fd0c30598" data-tracking-id="JTnrK2ZD4w0oMeQE6u5lLg==">
#        <a class="result-card__full-card-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_job-result-card_result-card_full-click" data-tracking-will-navigate="" href="https://es.linkedin.com/jobs/view/programador-rpg-400-madrid-madrid-at-serem-consultor%C3%ADa-empresarial-2365648116?refId=e8242f45-cc09-41fb-9378-693fd0c30598&amp;trackingId=JTnrK2ZD4w0oMeQE6u5lLg%3D%3D&amp;position=1&amp;pageNum=0&amp;trk=public_jobs_job-result-card_result-card_full-click">
#         <span class="screen-reader-text">
#          Programador RPG 400, Madrid, Madrid
#         </span>
#        </a>
#        <img alt="serem. Consultoría empresarial" aria-hidden="true" class="artdeco-entity-image job-result-card artdeco-entity-image--company job-result-card--company artdeco-entity-image--square-4 job-result-card--square-4 result-card__image lazy-load" data-delayed-url="https://media-exp1.licdn.com/dms/image/C510BAQE1As99HbPykw/company-logo_100_100/0/1519922929062?e=1617840000&amp;v=beta&amp;t=3_iL-7oWBvw_O58tUpmeAR9OMgJR71fVqktE9XBqjN4" data-ghost-classes="artdeco-entity-image--ghost job-result-card--ghost artdeco-entity-image--ghost-company job-result-card--ghost-company" data-ghost-url="https://static-exp1.licdn.com/sc/h/7kn6tg2e0ek9dhugj8l8t4dgg"/>
#        <div class="result-card__contents job-result-card__contents">
#         <h3 class="result-card__title job-result-card__title">
#          Programador RPG 400, Madrid, Madrid
#         </h3>
#         <h4 class="result-card__subtitle job-result-card__subtitle">
#          <a class="result-card__subtitle-link job-result-card__subtitle-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_job-result-card_result-card_subtitle-click" data-tracking-will-navigate="" href="https://es.linkedin.com/company/serem-consultor-a-empresarial?trk=public_jobs_job-result-card_result-card_subtitle-click">
#           serem. Consultoría empresarial
#          </a>
#         </h4>
#         <div class="result-card__meta job-result-card__meta">
#          <span class="job-result-card__location">
#           Madrid
#          </span>
#          <p class="job-result-card__snippet">
#           Precisamos incorporar un perfil de Analista Programador en RPG AS* con al menos 5 años de ex... En Serem estamos comprometidos con ...
#          </p>
#          <time class="job-result-card__listdate--new" datetime="2021-01-02">
#           Hace 24 horas
#          </time>
#         </div>
#        </div>
#       </li>
#      </ul>
#      <div class="inline-notification see-more-jobs__viewed-all hidden" role="alert" type="success">
#       <icon class="inline-notification__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/9oc5lgfcwxycgod8yjbt6dcgn">
#       </icon>
#       <p class="inline-notification__text">
#        Has visto todos los empleos para esta búsqueda
#       </p>
#      </div>
#     </section>
#    </div>
#    <section class="results__detail-view">
#     <div class="details-pane__loader details-pane__loader--hide">
#      <div class="large-loader">
#       <img alt="large loading spinner" aria-hidden="true" class="large-loader__icon lazy-load" data-delayed-url="https://static-exp1.licdn.com/sc/h/8u73kvqtfd00l1wdhykn4p0fp"/>
#      </div>
#     </div>
#     <div class="details-pane__content">
#     </div>
#    </section>
#   </main>
#   <form action="https://www.linkedin.com/uas/login-submit" class="google-one-tap" method="post">
#    <input name="loginCsrfParam" type="hidden" value="4d449a0a-bf5d-4597-8e29-7c543558150d">
#     <input name="session_redirect" type="hidden" value="https://es.linkedin.com/jobs/search?keywords=inform%C3%A1tica&amp;location=Madrid%2C%2BComunidad%2Bde%2BMadrid%2C%2BEspa%C3%B1a&amp;trk=homepage-jobseeker_jobs-search-bar_search-submit&amp;f_TP=1&amp;sortBy=DD&amp;f_PP=103374081&amp;redirect=false&amp;position=1&amp;pageNum=0">
#      <input name="trk" type="hidden" value="public_jobs_google-one-tap-submit">
#       <div class="google-one-tap__container" data-tracking-control-name="public_jobs_google-one-tap" id="google-one-tap__container">
#       </div>
#       <div class="loader loader--full-screen">
#        <div class="loader__container">
#         <icon class="loader__icon loader__icon--default" data-delayed-url="https://static-exp1.licdn.com/sc/h/ddi43qwelxeqjxdd45pe3fvs1" data-svg-class-name="loader__icon-svg--large">
#         </icon>
#        </div>
#       </div>
#      </input>
#     </input>
#    </input>
#   </form>
#   <div class="toasts toasts--bottom" data-close-toast-string="Cerrar" id="toasts" type="bottom">
#   </div>
#   <code id="i18n_redirected_from_deleted_alert" style="display: none;">
#    <!--"Esta alerta de empleo se ha desactivado."-->
#   </code>
#   <div>
#    <div class="modal create-alert-modal guest-job-alert-modal" data-outlet="create-alert-modal-outlet" id="create-alert-modal">
#     <div class="modal__overlay create-alert-modal__overlay guest-job-alert-modal__overlay">
#      <section aria-labelledby="create-alert-modal-modal-header" aria-modal="true" class="modal__wrapper create-alert-modal__wrapper guest-job-alert-modal__wrapper" role="dialog" tabindex="-1">
#       <header class="modal__header create-alert-modal__header guest-job-alert-modal__header">
#        <h2 class="modal__title create-alert-modal__title guest-job-alert-modal__title" id="create-alert-modal-modal-header">
#         Crear alerta de empleo
#        </h2>
#        <button aria-label="Descartar" class="modal__dismiss create-alert-modal__dismiss guest-job-alert-modal__dismiss modal__dismiss--with-icon create-alert-modal__dismiss--with-icon guest-job-alert-modal__dismiss--with-icon" data-tracking-control-name="public_jobs_create-alert-modal_modal_dismiss">
#         <icon class="modal__dismiss-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/44ge8ey0omn5oqp0k388nhe7g">
#         </icon>
#        </button>
#       </header>
#       <main class="modal__main create-alert-modal__main guest-job-alert-modal__main">
#        <form class="create-alert-form">
#         <div class="create-alert-form__body">
#          <p class="create-alert-form__header">
#           Recibe actualizaciones por email sobre nuevos anuncios de empleo de «
#           <strong class="break-word">
#            Informática
#           </strong>
#           » en
#           <strong>
#            España
#           </strong>
#          </p>
#          <p class="create-alert-form__subline">
#          </p>
#          <section class="dismissable-input create-alert-form-input">
#           <input aria-label="Dirección de email*" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_create-alert-modal_email-address_dismissable-input" maxlength="500" name="emailAddress" placeholder="Dirección de email*" required="" type="text" value=""/>
#           <button class="dismissable-input__button" data-tracking-control-name="public_jobs_create-alert-modal_email-address_dismissable-input-clear" type="button">
#            <label class="screen-reader-text">
#             Descartar
#            </label>
#            <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7">
#            </icon>
#           </button>
#          </section>
#          <input name="jserpUrl" type="hidden" value="https://es.linkedin.com/jobs/search?keywords=inform%C3%A1tica&amp;location=Madrid%2C%2BComunidad%2Bde%2BMadrid%2C%2BEspa%C3%B1a&amp;trk=homepage-jobseeker_jobs-search-bar_search-submit&amp;f_TP=1&amp;sortBy=DD&amp;f_PP=103374081&amp;redirect=false&amp;position=1&amp;pageNum=0">
#           <input name="pageType" type="hidden" value="JSERP">
#            <input name="keywords" type="hidden" value="Informática">
#             <code id="i18n_create_alert_invalid_email" style="display: none;">
#              <!--"Introduce una dirección de email válida"-->
#             </code>
#             <code id="i18n_generic_error_message" style="display: none;">
#              <!--"No se ha podido crear la alerta de empleo. Vuelve a intentarlo más tarde."-->
#             </code>
#             <p class="create-alert-error-message create-alert-error-message--email" role="alert">
#              <icon class="create-alert-error-message__icon lazy-load">
#              </icon>
#              <span class="create-alert-error-message__container">
# ...
#            <div class="guest-input create-alert-sign-in-form">
#             <div class="guest-input__input-container create-alert-sign-in-form__input-container">
#              <input autocomplete="username" class="guest-input__field create-alert-sign-in-form__field" id="session_key" name="session_key" placeholder=" " required="" type="text"/>
#              <label class="guest-input__label create-alert-sign-in-form__label" for="session_key">
#               Email o teléfono
#              </label>
#             </div>
#             <p class="guest-input__message create-alert-sign-in-form__message hidden" for="session_key" role="alert">
#             </p>
#            </div>
#            <div class="guest-input create-alert-sign-in-form">
#             <div class="guest-input__input-container create-alert-sign-in-form__input-container">
#              <input autocomplete="current-password" class="guest-input__field create-alert-sign-in-form__field" id="session_password" name="session_password" placeholder=" " required="" type="password"/>
#              <label class="guest-input__label create-alert-sign-in-form__label" for="session_password">
#               Contraseña
#              </label>
#              <button aria-label="Mostrar tu contraseña de LinkedIn" class="sign-in-form__password-visibility-toggle create-alert-sign-in-form__password-visibility-toggle" data-tracking-control-name="public_jobs_create-alert-modal_sign-in-password-visibility-toggle-btn" type="button">
#               Mostrar
#              </button>
#             </div>
#             <p class="guest-input__message create-alert-sign-in-form__message hidden" for="session_password" role="alert">
#             </p>
#            </div>
#            <input name="session_redirect" type="hidden" value="https://es.linkedin.com/jobs/search?keywords=inform%C3%A1tica&amp;location=Madrid%2C%2BComunidad%2Bde%2BMadrid%2C%2BEspa%C3%B1a&amp;trk=homepage-jobseeker_jobs-search-bar_search-submit&amp;f_TP=1&amp;sortBy=DD&amp;f_PP=103374081&amp;redirect=false&amp;position=1&amp;pageNum=0"/>
#           </div>
#           <div class="sign-in-form__footer create-alert-sign-in-form__footer">
#            <a class="sign-in-form__forgot-password create-alert-sign-in-form__forgot-password" data-tracking-control-name="public_jobs_create-alert-modal_forgot_password" data-tracking-will-navigate="" href="https://www.linkedin.com/uas/request-password-reset?trk=public_jobs_create-alert-modal_forgot_password">
#             ¿Has olvidado tu contraseña?
#            </a>
#            <input name="trk" type="hidden" value="public_jobs_create-alert-modal_sign-in-submit">
#             <button class="sign-in-form__submit-btn create-alert-sign-in-form__submit-btn" data-tracking-control-name="public_jobs_create-alert-modal_sign-in-submit-btn" data-tracking-litms="" type="submit">
#              Iniciar sesión
#             </button>
#            </input>
#           </div>
#          </input>
#         </form>
#        </div>
#       </main>
#      </section>
#     </div>
#    </div>
#   </div>
#   <div aria-describedby="cta-modal-subheader" aria-labelledby="cta-modal-header" class="cta-modal" data-impression-id="public_jobs_cta-modal" role="dialog">
#    <h2 class="cta-modal__header" id="cta-modal-header">
#     Has cerrado sesión
#    </h2>
#    <h3 class="cta-modal__subheader" id="cta-modal-subheader">
#     Inicia sesión para no perderte nada
#    </h3>
#    <a class="cta-modal__primary-btn" data-tracking-control-name="conversion-modal-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?emailAddress=&amp;fromSignIn=true&amp;session_redirect=https%3A%2F%2Fes.linkedin.com%2Fjobs%2Fsearch%3Fkeywords%3Dinform%25C3%25A1tica%26location%3DMadrid%252C%252BComunidad%252Bde%252BMadrid%252C%252BEspa%25C3%25B1a%26trk%3Dhomepage-jobseeker_jobs-search-bar_search-submit%26f_TP%3D1%26sortBy%3DDD%26f_PP%3D103374081%26redirect%3Dfalse%26position%3D1%26pageNum%3D0&amp;trk=public_jobs_conversion-modal-signin">
#     Iniciar sesión
#    </a>
#    <a class="cta-modal__secondary-btn" data-tracking-control-name="conversion-modal-join" data-tracking-will-navigate="" href="https://www.linkedin.com/signup/cold-join?source=jobs_registration&amp;session_redirect=https%3A%2F%2Fes.linkedin.com%2Fjobs%2Fsearch%3Fkeywords%3Dinform%25C3%25A1tica%26location%3DMadrid%252C%252BComunidad%252Bde%252BMadrid%252C%252BEspa%25C3%25B1a%26trk%3Dhomepage-jobseeker_jobs-search-bar_search-submit%26f_TP%3D1%26sortBy%3DDD%26f_PP%3D103374081%26redirect%3Dfalse%26position%3D1%26pageNum%3D0&amp;trk=public_jobs_conversion-modal-join">
#     Unirse ahora
#    </a>
#    <button aria-label="Descartar" class="cta-modal__dismiss-btn" data-tracking-control-name="public_jobs_dismiss">
#     <icon class="cta-modal__dismiss-icon onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/44ge8ey0omn5oqp0k388nhe7g">
#     </icon>
#    </button>
#   </div>
#   <footer class="li-footer">
#    <ul class="li-footer__list">
#     <li class="li-footer__item">
#      <span class="sr-only">
#       LinkedIn
#      </span>
#      <icon class="li-footer__copy-logo" data-delayed-url="https://static-exp1.licdn.com/sc/h/b11vnqql8f4abtysggvq9v836">
#      </icon>
#      <span class="li-footer__copy-text">
#       © 2020
#      </span>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-about" data-tracking-will-navigate="" href="https://about.linkedin.com?trk=public_jobs_footer-about">
#       Acerca de
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-accessibility" data-tracking-will-navigate="" href="https://www.linkedin.com/accessibility?trk=public_jobs_footer-accessibility">
#       Accesibilidad
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-user-agreement" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/user-agreement?trk=public_jobs_footer-user-agreement">
#       Condiciones de uso
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-privacy-policy" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/privacy-policy?trk=public_jobs_footer-privacy-policy">
#       Política de privacidad
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-cookie-policy" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/cookie-policy?trk=public_jobs_footer-cookie-policy">
#       Política de cookies
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-copyright-policy" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/copyright-policy?trk=public_jobs_footer-copyright-policy">
#       Política de copyright
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-brand-policy" data-tracking-will-navigate="" href="https://brand.linkedin.com/policies?trk=public_jobs_footer-brand-policy">
#       Política de marca
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-guest-controls" data-tracking-will-navigate="" href="https://www.linkedin.com/psettings/guest-controls?trk=public_jobs_footer-guest-controls">
#       Controles de invitados
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <a class="li-footer__item-link" data-tracking-control-name="public_jobs_footer-community-guide" data-tracking-will-navigate="" href="https://www.linkedin.com/help/linkedin/answer/34593?lang=es&amp;trk=public_jobs_footer-community-guide">
#       Directrices comunitarias
#      </a>
#     </li>
#     <li class="li-footer__item">
#      <div class="collapsible-dropdown language-selector collapsible-dropdown--footer language-selector--footer collapsible-dropdown--up language-selector--up">
#       <ul class="collapsible-dropdown__list language-selector__list hidden" role="menu">
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="ar_AE" data-tracking-control-name="language-selector-ar_AE" lang="ar_AE">
#          العربية (árabe)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="cs_CZ" data-tracking-control-name="language-selector-cs_CZ" lang="cs_CZ">
#          Čeština (checo)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="da_DK" data-tracking-control-name="language-selector-da_DK" lang="da_DK">
#          Dansk (danés)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="de_DE" data-tracking-control-name="language-selector-de_DE" lang="de_DE">
#          Deutsch (alemán)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="en_US" data-tracking-control-name="language-selector-en_US" lang="en_US">
#          English (inglés)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link language-selector__link--selected" data-locale="es_ES" data-tracking-control-name="language-selector-es_ES" lang="es_ES">
#          <strong>
#           Español (Spanish)
#          </strong>
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="fr_FR" data-tracking-control-name="language-selector-fr_FR" lang="fr_FR">
#          Français (francés)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="in_ID" data-tracking-control-name="language-selector-in_ID" lang="in_ID">
#          Bahasa Indonesia (indonesio)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="it_IT" data-tracking-control-name="language-selector-it_IT" lang="it_IT">
#          Italiano (italiano)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="ja_JP" data-tracking-control-name="language-selector-ja_JP" lang="ja_JP">
#          日本語 (japonés)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="ko_KR" data-tracking-control-name="language-selector-ko_KR" lang="ko_KR">
#          한국어 (coreano)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="ms_MY" data-tracking-control-name="language-selector-ms_MY" lang="ms_MY">
#          Bahasa Malaysia (malayo)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="nl_NL" data-tracking-control-name="language-selector-nl_NL" lang="nl_NL">
#          Nederlands (neerlandés)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="no_NO" data-tracking-control-name="language-selector-no_NO" lang="no_NO">
#          Norsk (noruego)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="pl_PL" data-tracking-control-name="language-selector-pl_PL" lang="pl_PL">
#          Polski (polaco)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="pt_BR" data-tracking-control-name="language-selector-pt_BR" lang="pt_BR">
#          Português (portugués)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="ro_RO" data-tracking-control-name="language-selector-ro_RO" lang="ro_RO">
#          Română (rumano)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="ru_RU" data-tracking-control-name="language-selector-ru_RU" lang="ru_RU">
#          Русский (ruso)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="sv_SE" data-tracking-control-name="language-selector-sv_SE" lang="sv_SE">
#          Svenska (sueco)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="th_TH" data-tracking-control-name="language-selector-th_TH" lang="th_TH">
#          ภาษาไทย (tailandés)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="tl_PH" data-tracking-control-name="language-selector-tl_PH" lang="tl_PH">
#          Tagalog (tagalo)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="tr_TR" data-tracking-control-name="language-selector-tr_TR" lang="tr_TR">
#          Türkçe (turco)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="zh_CN" data-tracking-control-name="language-selector-zh_CN" lang="zh_CN">
#          简体中文 (chino simplificado)
#         </button>
#        </li>
#        <li class="language-selector__item" role="menuitem">
#         <button class="language-selector__link" data-locale="zh_TW" data-tracking-control-name="language-selector-zh_TW" lang="zh_TW">
#          正體中文 (chino (tradicional))
#         </button>
#        </li>
#       </ul>
#       <button aria-expanded="false" class="language-selector__button" data-tracking-control-name="footer-lang-dropdown_trigger">
#        <span class="language-selector__label-text">
#         Idioma
#        </span>
#        <icon class="language-selector__label-chevron" data-delayed-url="https://static-exp1.licdn.com/sc/h/cyolgscd0imw2ldqppkrb84vo">
#        </icon>
#       </button>
#      </div>
#     </li>
#    </ul>
#   </footer>
#   <section id="json-refs">
#    <code id="requestSubdomain" style="display: none;">
#     <!--"es"-->
#    </code>
#    <code id="dust-var-pageKey" style="display: none;">
#     <!--"d_jobs_guest_search"-->
#    </code>
#    <code id="dust-var-savedSearchList" style="display: none;">
#     <!--false-->
#    </code>
#    <code id="dust-var-savedSearchUrl" style="display: none;">
#     <!--false-->
#    </code>
#    <code id="dust-var-isRedirectedFromDeletedAlert" style="display: none;">
#     <!--false-->
#    </code>
#    <code id="dust-var-currentJobId" style="display: none;">
#     <!--"2365648116"-->
#    </code>
#    <code id="dust-var-currentSearchId" style="display: none;">
#     <!--"e8242f45-cc09-41fb-9378-693fd0c30598"-->
#    </code>
#    <code id="dust-var-totalResults" style="display: none;">
#     <!--"1"-->
#    </code>
#    <code id="dust-var-resultsPerPage" style="display: none;">
#     <!--"25"-->
#    </code>
#    <code id="dust-var-areBingSearchResultsAvailable" style="display: none;">
#     <!--false-->
#    </code>
#    <code id="isSkipUnifyApplySubmitEnabled" style="display: none;">
#     <!--false-->
#    </code>
#   </section>
#   <script data-delayed-url="https://static-exp1.licdn.com/sc/h/9x1ka0d4advijnuxgxnyns6ne" data-module-id="google-one-tap-lib">
#   </script>
#  </body>
# </html>

# %%
for job in soup.find_all('a'):
    if job.get('class') == ['result-card__full-card-link']:
        print(job.get('href'))
# Out:
# https://es.linkedin.com/jobs/view/programador-rpg-400-madrid-madrid-at-serem-consultor%C3%ADa-empresarial-2365648116?refId=e8242f45-cc09-41fb-9378-693fd0c30598&trackingId=JTnrK2ZD4w0oMeQE6u5lLg%3D%3D&position=1&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click

# %%
for job in soup.find_all('a'):
    if job.get('class') == ['result-card__full-card-link']:
        j = requests.get(job.get('href'))
        s = BeautifulSoup(j.content, 'html.parser')
        print(job.get_text())
        print(job.get('href'))
        for des in s.find_all('h3'):
            if des.get('class') == ['job-criteria__subheader']:
                print(des.get_text())
        for des in s.find_all('span'):
            if des.get('class') == ['job-criteria__text', 'job-criteria__text--criteria']:
                print(des.get_text())
# Out:
# Programador RPG 400, Madrid, Madrid
# https://es.linkedin.com/jobs/view/programador-rpg-400-madrid-madrid-at-serem-consultor%C3%ADa-empresarial-2365648116?refId=e8242f45-cc09-41fb-9378-693fd0c30598&trackingId=JTnrK2ZD4w0oMeQE6u5lLg%3D%3D&position=1&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click
# Nivel de antigüedad
# Tipo de empleo
# Función laboral
# Sectores
# Sin experiencia
# Jornada completa
# Ingeniería
# Tecnología de la información
# Servicios y tecnologías de la información
# Software
# Recursos humanos

# %%
todayJobs = []

for job in soup.find_all('a'):
    if job.get('class') == ['result-card__full-card-link']:
        oneJob = []
        j = requests.get(job.get('href'))
        s = BeautifulSoup(j.content, 'html.parser')
        oneJob.append(job.get_text())
        oneJob.append(job.get('href'))
        for des in s.find_all('h3'):
            if des.get('class') == ['job-criteria__subheader']:
                oneJob.append(des.get_text())
        for des in s.find_all('span'):
            if des.get('class') == ['job-criteria__text', 'job-criteria__text--criteria']:
                oneJob.append(des.get_text())
        todayJobs.append(oneJob)

# %%
print(todayJobs)
# Out:
# [['Programador RPG 400, Madrid, Madrid', 'https://es.linkedin.com/jobs/view/programador-rpg-400-madrid-madrid-at-serem-consultor%C3%ADa-empresarial-2365648116?refId=e8242f45-cc09-41fb-9378-693fd0c30598&trackingId=JTnrK2ZD4w0oMeQE6u5lLg%3D%3D&position=1&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click', 'Nivel de antigüedad', 'Tipo de empleo', 'Función laboral', 'Sectores', 'Sin experiencia', 'Jornada completa', 'Ingeniería', 'Tecnología de la información', 'Servicios y tecnologías de la información ', 'Software', 'Recursos humanos']]

# %%
for job in todayJobs:
    print('Nombre:', job[0])
    print(job[2] + ':', job[6])
    print(job[3] + ':', job[7])
    print(job[4] + ':', job[8])
    print(job[5] + ':', job[9] + '...')
    print('Link:', job[1])
    print('\n\n\n')
# Out:
# Nombre: Programador RPG 400, Madrid, Madrid
# Nivel de antigüedad: Sin experiencia
# Tipo de empleo: Jornada completa
# Función laboral: Ingeniería
# Sectores: Tecnología de la información...
# Link: https://es.linkedin.com/jobs/view/programador-rpg-400-madrid-madrid-at-serem-consultor%C3%ADa-empresarial-2365648116?refId=e8242f45-cc09-41fb-9378-693fd0c30598&trackingId=JTnrK2ZD4w0oMeQE6u5lLg%3D%3D&position=1&pageNum=0&trk=public_jobs_job-result-card_result-card_full-click
